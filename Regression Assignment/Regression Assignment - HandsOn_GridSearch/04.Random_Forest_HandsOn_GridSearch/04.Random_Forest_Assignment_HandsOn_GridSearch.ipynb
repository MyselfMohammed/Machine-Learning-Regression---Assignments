# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV #Here cv refers to Cross Validation
from sklearn.ensemble import RandomForestRegressor

#Creating a Dictionary for Playable Parameters
param_grid = {'n_estimators':[50,100], 'random_state':[0], 'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features':[None,'sqrt','log2']}

#if refit = false then final model will be considered as Last Combination of parameter_grid like (linear,3000,scale)
#n_jobs = -1 refers to Run all the Models Parallely
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1)

#All the above steps are called "Procedure Load"

#Model Creation
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100], 'random_state': [0]},
#              verbose=3)

# %%
#print Best Parameter after Tuning the Playable Parameters
#print(grid.best_params_)

#To get all the results of GridSearchCV
results = grid.cv_results_
#print(results)

print("The R_Score Value for the Best Parameter {}:".format(grid.best_params_))
# Out:
# The R_Score Value for the Best Parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100, 'random_state': 0}:

# %%
#To make All the Results into Tabular Format

table = pd.DataFrame.from_dict(results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.260976      0.008577         0.011761        0.005428
# 1        0.488253      0.009560         0.021479        0.006776
# 2        0.188480      0.002181         0.009802        0.001437
# 3        0.374260      0.011677         0.014140        0.003575
# 4        0.194543      0.003446         0.008418        0.005999
# 5        0.373943      0.012639         0.021376        0.005784
# 6        0.244368      0.004504         0.012358        0.006649
# 7        0.510449      0.068764         0.020662        0.008919
# 8        0.274972      0.081962         0.023036        0.006160
# 9        0.863512      0.016867         0.038744        0.005559
# 10       0.441622      0.013840         0.023339        0.004822
# 11       0.859634      0.015330         0.038958        0.007855
# 12       2.449165      0.018398         0.020870        0.002747
# 13       4.880841      0.066349         0.036881        0.006954
# 14       1.425928      0.050875         0.023947        0.005002
# 15       2.953952      0.048771         0.037991        0.006256
# 16       1.475096      0.022592         0.026712        0.006197
# 17       2.852357      0.012991         0.039793        0.007840
# 18       0.638309      0.012950         0.027706        0.004564
# 19       1.310580      0.038314         0.035942        0.006913
# 20       0.482239      0.005977         0.019035        0.003131
# 21       0.929572      0.010000         0.036214        0.003825
# 22       0.479381      0.017474         0.022939        0.006416
# 23       0.891116      0.113236         0.035862        0.007670
#
#    param_criterion param_max_features param_n_estimators param_random_state  \
# 0    squared_error               None                 50                  0
# 1    squared_error               None                100                  0
# 2    squared_error               sqrt                 50                  0
# 3    squared_error               sqrt                100                  0
# 4    squared_error               log2                 50                  0
# 5    squared_error               log2                100                  0
# 6     friedman_mse               None                 50                  0
# 7     friedman_mse               None                100                  0
# 8     friedman_mse               sqrt                 50                  0
# 9     friedman_mse               sqrt                100                  0
# 10    friedman_mse               log2                 50                  0
# 11    friedman_mse               log2                100                  0
# 12  absolute_error               None                 50                  0
# 13  absolute_error               None                100                  0
# 14  absolute_error               sqrt                 50                  0
# 15  absolute_error               sqrt                100                  0
# 16  absolute_error               log2                 50                  0
# 17  absolute_error               log2                100                  0
# 18         poisson               None                 50                  0
# 19         poisson               None                100                  0
# 20         poisson               sqrt                 50                  0
# 21         poisson               sqrt                100                  0
# 22         poisson               log2                 50                  0
# 23         poisson               log2                100                  0
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.851993
# 1   {'criterion': 'squared_error', 'max_features':...           0.848257
# 2   {'criterion': 'squared_error', 'max_features':...           0.855685
# 3   {'criterion': 'squared_error', 'max_features':...           0.858905
# 4   {'criterion': 'squared_error', 'max_features':...           0.855685
# 5   {'criterion': 'squared_error', 'max_features':...           0.858905
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.851563
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.848151
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.854044
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857583
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.854044
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.857583
# 12  {'criterion': 'absolute_error', 'max_features'...           0.835832
# 13  {'criterion': 'absolute_error', 'max_features'...           0.836477
# 14  {'criterion': 'absolute_error', 'max_features'...           0.855615
# 15  {'criterion': 'absolute_error', 'max_features'...           0.860535
# 16  {'criterion': 'absolute_error', 'max_features'...           0.855615
# 17  {'criterion': 'absolute_error', 'max_features'...           0.860535
# 18  {'criterion': 'poisson', 'max_features': None,...           0.850678
# 19  {'criterion': 'poisson', 'max_features': None,...           0.847699
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858807
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.861514
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.858807
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861514
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.765666           0.851253           0.818036
# 1            0.766556           0.854000           0.821861
# 2            0.773388           0.854781           0.828955
# 3            0.775694           0.857998           0.826291
# 4            0.773388           0.854781           0.828955
# 5            0.775694           0.857998           0.826291
# 6            0.766200           0.851524           0.817263
# 7            0.767175           0.854361           0.821607
# 8            0.774676           0.855767           0.828459
# 9            0.777067           0.859283           0.825962
# 10           0.774676           0.855767           0.828459
# 11           0.777067           0.859283           0.825962
# 12           0.764210           0.852806           0.829932
# 13           0.764813           0.850267           0.827488
# 14           0.780683           0.859853           0.828303
# 15           0.784569           0.860666           0.825458
# 16           0.780683           0.859853           0.828303
# 17           0.784569           0.860666           0.825458
# 18           0.769006           0.854793           0.816521
# 19           0.768470           0.855237           0.820087
# 20           0.773536           0.856636           0.829932
# 21           0.776353           0.864575           0.828893
# 22           0.773536           0.856636           0.829932
# 23           0.776353           0.864575           0.828893
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.834585         0.824307        0.031863               21
# 1            0.833606         0.824856        0.031246               20
# 2            0.838696         0.830301        0.030183               15
# 3            0.839129         0.831603        0.030505                9
# 4            0.838696         0.830301        0.030183               15
# 5            0.839129         0.831603        0.030505                9
# 6            0.834909         0.824292        0.031693               22
# 7            0.834385         0.825136        0.031117               19
# 8            0.838687         0.830327        0.029598               13
# 9            0.839342         0.831848        0.030022                7
# 10           0.838687         0.830327        0.029598               13
# 11           0.839342         0.831848        0.030022                7
# 12           0.833835         0.823323        0.030575               23
# 13           0.833402         0.822489        0.029792               24
# 14           0.838440         0.832579        0.028356                5
# 15           0.842216         0.834689        0.028272                1
# 16           0.838440         0.832579        0.028356                5
# 17           0.842216         0.834689        0.028272                1
# 18           0.836719         0.825543        0.031273               18
# 19           0.836313         0.825561        0.030905               17
# 20           0.836260         0.831034        0.030859               11
# 21           0.838063         0.833880        0.031804                3
# 22           0.836260         0.831034        0.030859               11
# 23           0.838063         0.833880        0.031804                3

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
gender_male_input = float(input("Gender Male 0 or 1:"))
smoker_yes_input = float(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 30
# BMI: 40
# Children: 1
# Gender Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
#prediction
#Keyword - predict is function of Application 
Future_Prediction = grid.predict([[age_input, bmi_input, children_input, gender_male_input, smoker_yes_input]])
print("Future_Prediction{}:".format(Future_Prediction))
# Out:
# Future_Prediction[8234.2297901]:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Naming the Model with its extension .sav
import pickle
filename = "finalized_model_RandomForest_HandsOn_GridSearch_Assignment.sav"

#Model will be saved in respective path, once after the below Code Execution
# Keyword - wb refers to "write binary"
pickle.dump(grid,open(filename,'wb'))

# %%
# Load the Saved Model and check the same to send it for Phase-02 (Deployment)
# # Keyword - rb refers to "read binary"

loaded_model=pickle.load(open("finalized_model_RandomForest_HandsOn_GridSearch_Assignment.sav",'rb'))
result = loaded_model.predict([[age_input, bmi_input, children_input, gender_male_input, smoker_yes_input]]) 
result
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([8234.2297901])
