# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#Splitting Train and Test Set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV #Here cv refers to Cross Validation
from sklearn.ensemble import RandomForestRegressor

#Creating a Dictionary for Playable Parameters
param_grid = {'n_estimators':[50,100], 'random_state':[0], 'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
              'max_features':[None,'sqrt','log2']}

#if refit = false then final model will be considered as Last Combination of parameter_grid like (linear,3000,scale)
#n_jobs = -1 refers to Run all the Models Parallely
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1)

#All the above steps are called "Procedure Load"

#Model Creation
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100], 'random_state': [0]},
#              verbose=3)

# %%
#print Best Parameter after Tuning the Playable Parameters
#print(grid.best_params_)

#To get all the results of GridSearchCV
results = grid.cv_results_
#print(results)

print("The R_Score Value for the Best Parameter {}:".format(grid.best_params_))
# Out:
# The R_Score Value for the Best Parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100, 'random_state': 0}:

# %%
#To make All the Results into Tabular Format

table = pd.DataFrame.from_dict(results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007674      0.005431         0.004451        0.003364
# 1        0.003452      0.000917         0.002225        0.002148
# 2        0.004816      0.001357         0.002127        0.001967
# 3        0.003729      0.003007         0.002944        0.003024
# 4        0.006074      0.001213         0.001206        0.001127
# 5        0.004900      0.000920         0.001890        0.000635
# 6        0.006379      0.004361         0.003076        0.003139
# 7        0.002128      0.001302         0.004180        0.003023
# 8        0.013570      0.003200         0.002981        0.002448
# 9        0.013242      0.002721         0.002379        0.000793
# 10       0.012933      0.004595         0.002487        0.003154
# 11       0.009507      0.002184         0.002059        0.002532
# 12       0.006232      0.003975         0.000842        0.001032
# 13       0.003359      0.002200         0.001065        0.001329
# 14       0.002879      0.002472         0.004930        0.001161
# 15       0.003821      0.003254         0.000516        0.001032
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.668907
# 1   {'criterion': 'squared_error', 'max_features':...           0.678664
# 2   {'criterion': 'squared_error', 'max_features':...           0.736988
# 3   {'criterion': 'squared_error', 'max_features':...           0.709178
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.790659
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.343078
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.704958
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.654368
# 8   {'criterion': 'absolute_error', 'max_features'...           0.643935
# 9   {'criterion': 'absolute_error', 'max_features'...           0.702879
# 10  {'criterion': 'absolute_error', 'max_features'...           0.633502
# 11  {'criterion': 'absolute_error', 'max_features'...           0.680756
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.574733
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.762121
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.614586
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.625283
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.684482           0.658821           0.732083
# 1            0.572116           0.511705           0.603320
# 2            0.504727           0.611630           0.634980
# 3            0.328911           0.463024           0.629660
# 4            0.635391           0.531482           0.653239
# 5            0.532696           0.567033           0.591933
# 6            0.291658           0.690196           0.496292
# 7            0.639127           0.581160           0.485012
# 8            0.611518           0.635666           0.588973
# 9            0.636574           0.577219           0.424155
# 10           0.623747           0.647837           0.597428
# 11           0.655600           0.681513           0.629268
# 12           0.560131           0.622190           0.613809
# 13           0.637200           0.511811           0.617556
# 14           0.590816           0.676092           0.633329
# 15           0.615065           0.441027           0.677237
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.599074         0.668674        0.042923                1
# 1            0.495550         0.572271        0.066088               13
# 2            0.556271         0.608919        0.078379                6
# 3            0.611018         0.548358        0.135527               15
# 4            0.391464         0.600447        0.133130                7
# 5            0.544265         0.515801        0.088713               16
# 6            0.644219         0.565464        0.155547               14
# 7            0.603273         0.592588        0.059666               10
# 8            0.636216         0.623261        0.020311                5
# 9            0.583585         0.584882        0.092183               12
# 10           0.660063         0.632515        0.021460                3
# 11           0.344182         0.598264        0.128485                8
# 12           0.594365         0.593046        0.023242                9
# 13           0.630224         0.631782        0.079518                4
# 14           0.699884         0.642941        0.039887                2
# 15           0.598332         0.591389        0.079669               11

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
gender_male_input = float(input("Gender Male 0 or 1:"))
smoker_yes_input = float(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 30
# BMI: 40
# Children: 1
# Gender Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
#prediction
#Keyword - predict is function of Application 
Future_Prediction = grid.predict([[age_input, bmi_input, children_input, gender_male_input, smoker_yes_input]])
print("Future_Prediction{}:".format(Future_Prediction))
# Out:
# Future_Prediction[9378.9126139]:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Naming the Model with its extension .sav
import pickle
filename = "finalized_model_RandomForest_GridSearch_Assignment.sav"

#Model will be saved in respective path, once after the below Code Execution
# Keyword - wb refers to "write binary"
pickle.dump(grid,open(filename,'wb'))

# %%
# Load the Saved Model and check the same to send it for Phase-02 (Deployment)
# # Keyword - rb refers to "read binary"

loaded_model=pickle.load(open("finalized_model_RandomForest_GridSearch_Assignment.sav",'rb'))
result = loaded_model.predict([[age_input, bmi_input, children_input, gender_male_input, smoker_yes_input]]) 
result
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([9378.9126139])
